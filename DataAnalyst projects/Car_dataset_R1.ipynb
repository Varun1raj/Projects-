# %% [markdown]
# # CARS_DATASET

# %%
import pandas as pd
import sklearn as sas
import seaborn as sns
from matplotlib import pyplot as plt

# %%
## import the Car dataset 
car = pd.read_csv('C:/DATASETS/Dataset/Cars_data.csv')

# %%
## read the car dataset
car.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
## shape of data
car.shape
# Out:
# (432, 15)

# %%
##find the sum of missing values based on column
car.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
## fimd the duplicates
car.duplicated().sum()
# Out:
# 3

# %%
## remove the duplicates
###car.drop(car.duplicated().sum()).inplace = True 
car.drop_duplicates(inplace = True)
len(car)
# Out:
# 429

# %%
## Chek 
car.duplicated().sum()
# Out:
# 0

# %%
## find the missing values in dataset
missing_value = car.isnull().sum()
missing_value
# Out:
# Make           1
# Model          1
# Type           1
# Origin         1
# DriveTrain     1
# MSRP           1
# Invoice        1
# EngineSize     1
# Cylinders      3
# Horsepower     1
# MPG_City       1
# MPG_Highway    1
# Weight         1
# Wheelbase      1
# Length         1
# dtype: int64

# %%
##remove the missing vales
car.drop(missing_value,axis=0).inplace=True 
len(car)
# Out:
# 429

# %%
## in index 39 row missing
car.isnull().iloc[0:50,:]
# Out:
#      Make  Model   Type  Origin  DriveTrain   MSRP  Invoice  EngineSize  \
# 0   False  False  False   False       False  False    False       False
# 1   False  False  False   False       False  False    False       False
# 2   False  False  False   False       False  False    False       False
# 3   False  False  False   False       False  False    False       False
# 4   False  False  False   False       False  False    False       False
# 5   False  False  False   False       False  False    False       False
# 6   False  False  False   False       False  False    False       False
# 7   False  False  False   False       False  False    False       False
# 8   False  False  False   False       False  False    False       False
# 9   False  False  False   False       False  False    False       False
# 10  False  False  False   False       False  False    False       False
# 11  False  False  False   False       False  False    False       False
# ...

# %%
## giving the correct index 
car.index.isnull().sum()
# Out:
# 0

# %%
## drop the row that entire value is missing
car.drop(car.index[30],axis=0,inplace=True)

# %%
## check 
car.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
car.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
## distribution cylinders 
sns.displot(car['Cylinders'])

# %%
## distribution enginesize
sns.displot(car['EngineSize'])

# %%
## find the missing value row 
car.iloc[200:250,:]
# Out:
#            Make                            Model    Type  Origin DriveTrain  \
# 204      Jaguar              XKR convertible 2dr  Sports  Europe       Rear
# 205        Jeep            Grand Cherokee Laredo     SUV     USA      Front
# 206        Jeep                    Liberty Sport     SUV     USA        All
# 207        Jeep  Wrangler Sahara convertible 2dr     SUV     USA        All
# 208         Kia                       Sorento LX     SUV    Asia      Front
# 209         Kia                    Optima LX 4dr   Sedan    Asia      Front
# 210         Kia                   Rio 4dr manual   Sedan    Asia      Front
# 211         Kia                     Rio 4dr auto   Sedan    Asia      Front
# 212         Kia                      Spectra 4dr   Sedan    Asia      Front
# 213         Kia             Spectra GS 4dr hatch   Sedan    Asia      Front
# 214         Kia            Spectra GSX 4dr hatch   Sedan    Asia      Front
# ...

# %%
## find the the cylinders baised on the engicnesize
car['EngineSize'].unique()
# Out:
# array([3.5, 2. , 2.4, 3.2, 1.8, 3. , 2.7, 4.2, 4.4, 2.5, 3.4, 3.1, 3.8,
#        5.3, 4.6, 3.6, 6. , 1.6, 2.2, 4.3, 5.7, 2.8, 3.3, 4.7, 8.3, 3.7,
#        6.8, 4. , 3.9, 5.4, 2.3, 4.8, 1.4, 1.7, 4.5, 1.3, 5. , 2.6, 5.5,
#        5.6, 1.5, 1.9, 2.9])

# %%
## creating the subset to datafame cotain column cylinder, enginesize
car1 = car[['EngineSize','Cylinders']]
car1.head()
# Out:
#    EngineSize  Cylinders
# 0         3.5        6.0
# 1         2.0        4.0
# 2         2.4        4.0
# 3         3.2        6.0
# 4         3.5        6.0

# %%
## sorting the values enginesize
car2 = car1.drop_duplicates().reset_index(drop=True)
car2.sort_values('EngineSize')
# Out:
#     EngineSize  Cylinders
# 39         1.3        NaN
# 34         1.4        4.0
# 46         1.5        4.0
# 18         1.6        4.0
# 36         1.7        4.0
# 4          1.8        4.0
# 47         1.9        4.0
# 1          2.0        4.0
# 35         2.0        3.0
# 19         2.2        4.0
# 32         2.3        4.0
# 53         2.3        5.0
# 2          2.4        4.0
# 54         2.4        5.0
# 9          2.5        6.0
# 45         2.5        4.0
# 52         2.5        5.0
# 41         2.6        6.0
# 6          2.7        6.0
# 48         2.8        6.0
# 22         2.8        4.0
# 51         2.9        6.0
# 5          3.0        6.0
# 12         3.1        6.0
# 3          3.2        6.0
# 23         3.3        6.0
# 11         3.4        6.0
# 0          3.5        6.0
# 16         3.6        6.0
# 26         3.7        6.0
# 13         3.8        6.0
# 29         3.9        6.0
# 30         3.9        8.0
# 49         4.0        8.0
# ...

# %%
## find the mean value of enginesize - 1.4 
## group by
car.groupby('EngineSize').mean()['Cylinders']
# Out:
# C:\Users\Varun\AppData\Local\Temp\ipykernel_8320\2998046902.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   car.groupby('EngineSize').mean()['Cylinders']
# EngineSize
# 1.3          NaN
# 1.4     4.000000
# 1.5     4.000000
# 1.6     4.000000
# 1.7     4.000000
# 1.8     4.000000
# 1.9     4.000000
# 2.0     3.966667
# 2.2     4.000000
# 2.3     4.153846
# 2.4     4.043478
# 2.5     5.076923
# 2.6     6.000000
# 2.7     6.000000
# 2.8     5.000000
# 2.9     6.000000
# 3.0     6.000000
# 3.1     6.000000
# 3.2     6.000000
# 3.3     6.000000
# 3.4     6.000000
# 3.5     6.000000
# 3.6     6.000000
# 3.7     6.000000
# 3.8     6.000000
# 3.9     7.500000
# 4.0     6.500000
# 4.2     7.500000
# 4.3     7.000000
# 4.4     8.000000
# 4.5     8.000000
# 4.6     8.000000
# 4.7     8.000000
# ...

# %%
##filling the missing values in Cylinder with mean of 1.4 enginesize
car=car.fillna(4.0)

# %%
## check the null vales
car.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %% [markdown]
# #### Check what are differetnt types of makes in datasets. what is the count of each make in the data?

# %%
car['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %% [markdown]
# #### Show all the records where origin is Asia or Europe.

# %%
car[car['Origin'].isin(['Aisa','Europe'])]
# Out:
#       Make                      Model   Type  Origin DriveTrain      MSRP  \
# 7     Audi                A4 1.8T 4dr  Sedan  Europe      Front  $25,940
# 8     Audi     A41.8T convertible 2dr  Sedan  Europe      Front  $35,940
# 9     Audi                 A4 3.0 4dr  Sedan  Europe      Front  $31,840
# 10    Audi  A4 3.0 Quattro 4dr manual  Sedan  Europe        All  $33,430
# 11    Audi    A4 3.0 Quattro 4dr auto  Sedan  Europe        All  $34,480
# ..     ...                        ...    ...     ...        ...       ...
# 427  Volvo    C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo    C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo                 S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                        V40  Wagon  Europe      Front  $26,135
# 431  Volvo                       XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# #### Removing the all recordes (rows ) where weight is above 4000.

# %%
car[car['Weight']>4000]
##car[~(car['Weight']>4000)]
## Above condition is used to remove the rows that weight above 4000
# Out:
#            Make                           Model    Type  Origin DriveTrain  \
# 0         Acura                             MDX     SUV    Asia        All
# 15         Audi  A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 17         Audi              A6 4.2 Quattro 4dr   Sedan  Europe        All
# 18         Audi                A8 L Quattro 4dr   Sedan  Europe        All
# 20         Audi                        RS 6 4dr  Sports  Europe      Front
# ..          ...                             ...     ...     ...        ...
# 405  Volkswagen                      Touareg V6     SUV  Europe        All
# 415  Volkswagen                     Phaeton 4dr   Sedan  Europe      Front
# 416  Volkswagen                 Phaeton W12 4dr   Sedan  Europe      Front
# 419  Volkswagen                       Passat W8   Wagon  Europe      Front
# 420       Volvo                         XC90 T6     SUV  Europe        All
#
# ...

# %% [markdown]
# #### Increase all the values of MPG_city column by 3.

# %%
car['MPG_City']=car['MPG_City'].apply(lambda x:x+3)

# %%
car
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
### which continent have hight production.
### which car has maxprice.
### plot the grapf on production based on contient.
### which car company have lost of models.

# %%
car.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      20.0         23.0  4451.0
# 1         2.0        4.0       200.0      27.0         31.0  2778.0
# 2         2.4        4.0       200.0      25.0         29.0  3230.0
# 3         3.2        6.0       270.0      23.0         28.0  3575.0
# 4         3.5        6.0       225.0      21.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
var = car['Origin'].value_counts()
var
# Out:
# Asia      158
# USA       147
# Europe    123
# Name: Origin, dtype: int64

# %% [markdown]
# ### which continent have hight production.

# %%
### which continent have hight production.
x=['Asia','USA','EUROPE']
y=var
plt.xlabel('CONTINENTS')
plt.ylabel('PRODUCTION')
plt.title('CAR PRODUCTION COMPARISION')
plt.ylim(0,170)
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### which car has maxprice.

# %%
### which car has maxprice.
car.sort_values('MSRP',ascending=False)
# Out:
#               Make                   Model    Type  Origin DriveTrain  \
# 265  Mercedes-Benz               CL500 2dr   Sedan  Europe       Rear
# 273  Mercedes-Benz   SL500 convertible 2dr  Sports  Europe       Rear
# 6            Acura  NSX coupe 2dr manual S  Sports    Asia       Rear
# 204         Jaguar     XKR convertible 2dr  Sports  Europe       Rear
# 272  Mercedes-Benz                S500 4dr   Sedan  Europe        All
# ..             ...                     ...     ...     ...        ...
# 211            Kia            Rio 4dr auto   Sedan    Asia      Front
# 349         Saturn                Ion1 4dr   Sedan     USA      Front
# 386         Toyota         Echo 2dr manual   Sedan    Asia      Front
# 171        Hyundai        Accent 2dr hatch   Sedan    Asia      Front
# 210            Kia          Rio 4dr manual   Sedan    Asia      Front
#
#          MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# ...

# %% [markdown]
# ### which car company have lost of models.

# %%
car['Make'].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hummer', 'Hyundai',
#        'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover',
#        'Lexus', 'Lincoln', 'MINI', 'Mazda', 'Mercedes-Benz', 'Mercury',
#        'Mitsubishi', 'Nissan', 'Oldsmobile', 'Pontiac', 'Porsche', 'Saab',
#        'Saturn', 'Scion', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
car3 = car[['Make','Model']]
car_model = car3['Make'].value_counts()

# %%
x = ['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
       'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hummer', 'Hyundai',
       'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover',
       'Lexus', 'Lincoln', 'MINI', ' Mazda ' , ' Mercedes-Benz' , ' Mercury ',
       'Mitsubishi', 'Nissan', 'Oldsmobile', 'Pontiac', 'Porsche', 'Saab',
       'Saturn', 'Scion', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen',
       'Volvo']
y = car_model

plt.figure(figsize=(35,8))
plt.ylim(0,30)
plt.bar(x,y,width=0.5)

plt.xlabel('CAR COMPANIES')
plt.ylabel('NUMBER OF MODELS')
plt.title('CAR MODELS COMPARISION')
# Out:
# Text(0.5, 1.0, 'CAR MODELS COMPARISION')
